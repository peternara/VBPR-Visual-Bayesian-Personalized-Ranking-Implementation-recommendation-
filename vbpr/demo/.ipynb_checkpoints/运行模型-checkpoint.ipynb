# %%
# !python model_mock/train.py --model="BPR" --name="BPR"
# Out:
# loading dataset from:  model_mock/reviews_Movies_ALL_scraped.csv
# load_complex
# generate stats...
# user_count: 139138  item_count: 153436  reviews_count 1932230
# laoding images features from ... model_mock/image_features_Movies_and_TV.b
# count_read,  0 	 count_item,  0
# count_read,  10000000 	 count_item,  152081
# 提取iamge feature count: 152081
# 2019-05-23 06:24:40.010545: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2019-05-23 06:24:40.022884: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-23 06:24:40.024621: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x557c33ef4b00 executing computations on platform Host. Devices:
# 2019-05-23 06:24:40.024674: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# ...

# %%
import platform
platform.architecture()
# Out:
# ('64bit', '')

# %%
# !tar cvf logs_cbpr.tar logs/
# Out:
# logs/
# logs/.data-00000-of-00001.tempstate1085256640064772729
# logs/checkpoint
# logs/.index
# logs/test/
# logs/test/run-20190518065902/
# logs/test/run-20190518065902/events.out.tfevents.1558162743.instance-1
# logs/test/run-20190519043405/
# logs/test/run-20190519043405/events.out.tfevents.1558240445.instance-1
# logs/test/run-20190518014602/
# logs/test/run-20190518014602/events.out.tfevents.1558143962.instance-1
# logs/test/run-20190518162731/
# logs/test/run-20190518162731/events.out.tfevents.1558196851.instance-1
# logs/test/run-20190522044715/
# logs/test/run-20190522044715/events.out.tfevents.1558500435.instance-1
# logs/test/run-20190517104815/
# logs/test/run-20190517104815/events.out.tfevents.1558090095.instance-1
# logs/test/run-20190520062758/
# logs/test/run-20190520062758/events.out.tfevents.1558333678.instance-1
# logs/test/run-20190521112640/
# logs/test/run-20190521112640/events.out.tfevents.1558438000.instance-1
# logs/test/run-20190521150547/
# ...

# %%
# !ls
# Out:
# data					     logs_hbpr.tar   Untitled0.ipynb
# image_features_Clothing_Shoes_and_Jewelry.b  logs_vbpr2.tar  Untitled.ipynb
# logs					     model_mock      论文.ipynb
# logs_bpr2.tar				     model_mock.rar
# logs_cbpr.tar				     model_mock.tar

# %%
import numpy as np
a = np.arange(10)
#a.append((np.exp(20).astype('float64'))
b = np.ones(10)
b.reshape(1,10)
#a.reshape(10,1)
print(a.size, b.size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-92da6be97573> in <module>
#       2 a = np.arange(10)
#       3 #a.append((np.exp(20).astype('float64'))
# ----> 4 b = np.ones(10,10)
#       5 b.reshape(1,10)
#       6 #a.reshape(10,1)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     221
#     222     """
# --> 223     a = empty(shape, dtype, order)
#     224     multiarray.copyto(a, 1, casting='unsafe')
#     225     return a
#
# TypeError: data type not understood

# %%
! tar xvf logs_vbpr2.tar logs/
# Out:
# logs/
# logs/checkpoint
# logs/.index
# logs/test/
# logs/test/run-20190518065902/
# logs/test/run-20190518065902/events.out.tfevents.1558162743.instance-1
# logs/test/run-20190518014602/
# logs/test/run-20190518014602/events.out.tfevents.1558143962.instance-1
# logs/test/run-20190517104815/
# logs/test/run-20190517104815/events.out.tfevents.1558090095.instance-1
# logs/test/run-20190517152020/
# logs/test/run-20190517152020/events.out.tfevents.1558106420.instance-1
# logs/test/run-20190517135923/
# logs/test/run-20190517135923/events.out.tfevents.1558101563.instance-1
# logs/test/run-20190517114049/
# logs/test/run-20190517114049/events.out.tfevents.1558093250.instance-1
# logs/test/run-20190518064216/
# logs/test/run-20190518064216/events.out.tfevents.1558161737.instance-1
# logs/test/run-20190517170441/
# logs/test/run-20190517170441/events.out.tfevents.1558112682.instance-1
# logs/test/run-20190517095543/
# logs/test/run-20190517095543/events.out.tfevents.1558086943.instance-1
# ...

# %%
# !gdrive download 1rKE6VUhN1dK6DNixQFU9igIT13DZyq6a --force
# Out:
# ...
# Downloaded 1rKE6VUhN1dK6DNixQFU9igIT13DZyq6a at 18.5 MB/s, total 112.7 MB

# %%
# !gdrive upload logs_cbpr.tar
# Out:
# Uploading logs_cbpr.tar
# Uploaded 1pAUO8jP4UHZJuEjHKVzGDF5wsEMXpp9l at 17.5 MB/s, total 94.1 MB
